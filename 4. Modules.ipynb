# %% [markdown]
# # Problem 1

# %%
import math

# %%
math.fabs(round(-4.3))
# Out:
# 4.0

# %%
print math.ceil(math.sin(34.5))
# Out:
# 1.0

# %%
math.sin(34.5)
# Out:
# 0.057487478104924564

# %% [markdown]
# # Problem 2

# %%
import calendar
import datetime

year = datetime.datetime.now().year

print 'Current year is', year

while(not calendar.isleap(year)):
    year+=1
print 'The next leap year is ', year
# Out:
# Current year is 2016
# The next leap year is  2016

# %%
print 'There are %d leap years between 2000 and 2050' %calendar.leapdays(2000,2050+1)
# Out:
# There are 13 leap years between 2000 and 2050

# %%
print calendar.day_name[calendar.weekday(2016, 7, 29)]
# Out:
# Friday

# %% [markdown]
# # Problem 3

# %%
print 'boolean'.capitalize()
# Out:
# Boolean

# %%
print 'CO2 H20'.find('2')
# Out:
# 2

# %%
str = 'CO2 H20'
needle = '2'
print str.find(needle,str.find(needle)+1)
# Out:
# 5

# %%
print 'Boolean'.islower()
# Out:
# False

# %%
'MoNDaY'.lower().capitalize()
# Out:
# 'Monday'

# %%
"  Monday".strip()
# Out:
# 'Monday'

# %% [markdown]
# # Problem 4
# Because it is a string

# %% [markdown]
# # Problem 5
# Because maybe media module isn't effective enough and standard yet.
#
# If I need a non-standard library, we can google it

# %% [markdown]
# # Problem 6

# %%
# %matplotlib inline
from scipy import ndimage as nd
from scipy import misc
import numpy as np
import matplotlib.pyplot as plt
img = misc.imread('cat.jpg')

# note that is fucking imshow, not show
plt.imshow(img)
plt.imshow(img)

# %% [markdown]
# # Problem 7

# %%
img = misc.imread('cat.jpg')
img[:,:,0] = 0 #
plt.imshow(img)

# %% [markdown]
# # Problem 8

# %%
img = misc.imread('cat.jpg')
img[:,:,1] /= 2
plt.imshow(img)

# %% [markdown]
# # Problem 9

# %%
img = misc.imread('cat.jpg')
avg = np.sum(img, axis=2) /float(3)
#print img[1,1,:]
#print img_new[1,1]
img[:,:,0] = avg
img[:,:,1] = avg
img[:,:,2] = avg
#print img_new[1,1,:]
plt.imshow(img)
#plt.imshow(img.dot(a))

# %% [markdown]
# # Problem 10

# %%
img = misc.imread('cat.jpg')
img[:,:,0] *= 2

plt.imshow(img)
# When a value is larger than 255, it used 255 instead

# %% [markdown]
# # Problem 11
# Q: Media outlets such as newspapers and TV stations sometimes “enhance” photographs by recoloring them or digitally combine pictures of two people to make them appear together. Do you think they should be allowed to use only unmodified images? Given that almost all pictures and TV footage are now digital and have to be processed somehow for display, what would that rule actually mean in practice?
#
# I really don't understand what they are talking about

# %% [markdown]
# # Problem 12

# %% [markdown]
# a) Because type float is not very pricise.
# b) Lack of test cases
